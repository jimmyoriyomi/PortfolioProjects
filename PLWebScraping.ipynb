# %%
import requests

# %%
# Define URL to scrape
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
# Download page using get method, make request to server to download page HTML
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
data = requests.get(standings_url, headers=headers)

# %%
# Look at HTML string
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202501161" />\n<script>\n/* https://docs.osano.com/hc/en-us/articles/22469433444372-Google-Consent-Mode-v2  */\n  window.dataLayer = window.dataLayer ||[];\n      function gtag(){dataLayer.push(arguments);}\n      gtag(\'consent\',\'default\',{\n        \'ad_storage\':\'denied\',\n        \'analytics_storage\':\'denied\',\n        \'ad_user_data\':\'denied\',\n        \'ad_personalization\':\'denied\',\n        \'personalization_storage\':\'denied\',\n        \'functionality_storage\':\'granted\',\n        \'security_storage\':\'granted\',\n        \'wait_for_update\': 500\n      });\n      gtag("set", "ads_data_redaction", true);\n</script>\n<script src="https://cmp.osano.com/16CGnCU8UtNhM14sg/12669873-8cf8-41e2-be1f-1cb803cbffe0/osano.js"></script>\n<style>.osano-cm-widget{display: none;}</style> \n\n\n\n\n    <title>Premier League Stats | FBref.com</title>\n\n    \n    \n    <meta name="Description" content="Check out Stats for the 2024-2025 Premier League season.">\n    <link rel="canonical" href="https://fbref.com/en/comps/9/Premier-League-Stats" />\n        \n\t<link rel="alternate" href="https://fbref.com/en/comps/9/Premier-League-Stats" hreflang="x-default" />\n\t<link rel="alternate" href="https://fbref.com/it/comp/9/Statistiche-di-Premier-League" hreflang="it-it" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-fr" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-cd" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-ca" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-cm" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-ci" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-be" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-ma" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-gn" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-dz" />\n\t<link rel="alternate" href="https://fbref.com/fr/comps/9/Statistiques-Premier-League" hreflang="fr-ht" />\n\t<link rel="alternate" href="https://fbref.com/en/comps/9/Premier-League-Stats" hreflang="en" />\n\t<link rel="alternate" href="https://fbref.com/pt/comps/9/Premier-League-Estatisticas" hreflang="pt-br" />\n\t<link rel="alternate" href="https://fbref.com/pt/comps/9/Premier-League-Estatisticas" hreflang="pt-pt" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-es" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-mx" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-co" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-ar" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-cl" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-pe" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-us" />\n\t<link rel="alternate" href="https://fbref.com/es/comps/9/Estadisticas-de-Premier-League" hreflang="es-py" />\n\t<link rel="alternat ...

# %%
# Import BeautifulSoup library to parse HTML
from bs4 import BeautifulSoup
import time

# %%
# Check the response status code
if data.status_code == 200:
    print("Request successful")
    # Initialize soup object using HTML
    soup = BeautifulSoup(data.text, 'html.parser')
    
    # Select the stats table with CSS Selector
    try:
        standings_table = soup.select('table.stats_table')[0]
        print("Found the stats table")
    except IndexError:
        print("Stats table not found")
else:
    # Print the HTTP status code if it's not 200
    print(f"Failed to retrieve the page. Status code: {data.status_code}")

# Add a delay to avoid too many requests
time.sleep(60)
# Out:
# Request successful
# Found the stats table

# %%
# Check stats table HTML
standings_table
# Out:
# <table class="stats_table sortable min_width force_mobilize" data-cols-to-freeze=",2" id="results2024-202591_overall"> <caption>Premier League Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr> <th aria-label="Rank" class="poptip sort_default_asc center" data-stat="rank" data-tip="&lt;strong&gt;Rank&lt;/strong&gt;&lt;br&gt;Squad finish in competition&lt;br&gt;Finish within the league or competition.&lt;br&gt;For knockout competitions may show final round reached.&lt;br&gt;Colors and arrows represent promotion/relegation or qualifiation for continental cups.&lt;br&gt;Trophy indicates team won league whether by playoffs or by leading the table.&lt;br&gt;Star indicates topped table in league USING another means of naming champion." scope="col">Rk</th> <th aria-label="Squad" class="poptip sort_default_asc center" data-stat="team" scope="col">Squad</th> <th aria-label="Matches Played" class="poptip center" data-stat="games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Wins" class="poptip center" data-stat="wins" data-tip="&lt;strong&gt;Wins&lt;/strong&gt;&lt;br&gt;Wins" scope="col">W</th> <th aria-label="Draws" class="poptip center" data-stat="ties" data-tip="&lt;strong&gt;Draws&lt;/strong&gt;&lt;br&gt;Draws" scope="col">D</th> <th aria-label="Losses" class="poptip center" data-stat="losses" data-tip="&lt;strong&gt;Losses&lt;/strong&gt;&lt;br&gt;Losses" scope="col">L</th> <th aria-label="Goals For" class="poptip center" data-stat="goals_for" data-tip="&lt;strong&gt;Goals For&lt;/strong&gt;&lt;br&gt;Goals For" scope="col">GF</th> <th aria-label="Goals Against" class="poptip center" data-stat="goals_against" data-tip="&lt;strong&gt;Goals Against&lt;/strong&gt;&lt;br&gt;Goals Against" scope="col">GA</th> <th aria-label="Goal Difference" class="poptip center" data-stat="goal_diff" data-tip="&lt;strong&gt;Goal Difference&lt;/strong&gt;&lt;br&gt;Goal Difference" scope="col">GD</th> <th aria-label="Points" class="poptip center" data-stat="points" data-tip="&lt;strong&gt;Points&lt;/strong&gt;&lt;br&gt;Most leagues are ordered by points.&lt;br&gt;Three for a win and one for a draw." scope="col">Pts</th> <th aria-label="Points/Match" class="poptip center" data-stat="points_avg" data-tip="&lt;strong&gt;Points/Match&lt;/strong&gt;&lt;br&gt;Points per Match Played" scope="col">Pts/MP</th> <th aria-label="xG" class="poptip center" data-filter="1" data-name="xG" data-stat="xg_for" data-tip="&lt;strong&gt;Expected Goals&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xG</th> <th aria-label="xG Allowed" class="poptip sort_default_asc center" data-stat="xg_against" data-tip="&lt;strong&gt;xG Allowed&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Allowed&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xGA</th> <th aria-label="xG Difference" class="poptip center" data-filter="1" data-name="xG Difference" data-stat="xg_diff" data-tip="&lt;strong&gt;xG Difference&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Expected Goals Difference&lt;/strong&gt;&lt;br&gt;xG totals include penalty kicks, but do not include penalty shootouts (unless otherwise noted).&lt;br&gt;Provided by Opta.&lt;br&gt;An underline indicates there is a match that is missing data, but will be updated when available." scope="col">xGD</th> <th aria-label="xG Difference/90" class="poptip hide_non_quals center" data-stat="xg_diff_per90" data-tip="&lt;str ...

# %%
# Find all a tags in our table
links = standings_table.find_all('a')

# %%
# Get href property of each link - goes through each a element and find value of href property
links = [l.get("href") for l in links]

# %%
# Filter links so we only have squad links
links = [l for l in links if '/squads/' in l]

# %%
links
# Out:
# ['/en/squads/822bd0ba/Liverpool-Stats',
#  '/en/squads/18bb7c10/Arsenal-Stats',
#  '/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  '/en/squads/b8fd03ef/Manchester-City-Stats',
#  '/en/squads/b2b47a98/Newcastle-United-Stats',
#  '/en/squads/cff3d9bb/Chelsea-Stats',
#  '/en/squads/4ba7cbea/Bournemouth-Stats',
#  '/en/squads/8602292d/Aston-Villa-Stats',
#  '/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  '/en/squads/fd962109/Fulham-Stats',
#  '/en/squads/cd051869/Brentford-Stats',
#  '/en/squads/19538871/Manchester-United-Stats',
#  '/en/squads/47c64c55/Crystal-Palace-Stats',
#  '/en/squads/7c21e445/West-Ham-United-Stats',
#  '/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  '/en/squads/d3fd31cc/Everton-Stats',
#  '/en/squads/a2d435b3/Leicester-City-Stats',
#  '/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  '/en/squads/b74092de/Ipswich-Town-Stats',
#  '/en/squads/33c895d4/Southampton-Stats']

# %%
# Turn links into full urls using Python format string
team_urls = [f"https://fbref.com{l}" for l in links]

# %%
team_urls
# Out:
# ['https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  'https://fbref.com/en/squads/b74092de/Ipswich-Town-Stats',
#  'https://fbref.com/en/squads/33c895d4/Southampton-Stats']

# %%
# Work with Chelsea url
team_url = team_urls[5]

# %%
# Use requests to get HTML from that URL
data = requests.get(team_url)
time.sleep(60)

# %%
import pandas as pd

# %%
from io import StringIO

# %%
html_data = StringIO(data.text)

# %%
# Convert Scores & Fixtures table to dataframe using string
matches = pd.read_html(html_data, match="Scores & Fixtures")

# %%
matches
# Out:
# [          Date   Time            Comp                Round  Day Venue Result  \
#  0   2024-08-18  16:30  Premier League          Matchweek 1  Sun  Home      L
#  1   2024-08-22  20:00         Conf Lg       Play-off round  Thu  Home      W
#  2   2024-08-25  14:00  Premier League          Matchweek 2  Sun  Away      W
#  3   2024-08-29  20:30         Conf Lg       Play-off round  Thu  Away      L
#  4   2024-09-01  13:30  Premier League          Matchweek 3  Sun  Home      D
#  5   2024-09-14  20:00  Premier League          Matchweek 4  Sat  Away      W
#  6   2024-09-21  12:30  Premier League          Matchweek 5  Sat  Away      W
#  7   2024-09-24  19:45         EFL Cup          Third round  Tue  Home      W
#  8   2024-09-28  15:00  Premier League          Matchweek 6  Sat  Home      W
#  9   2024-10-03  20:00         Conf Lg         League phase  Thu  Home      W
#  10  2024-10-06  14:00  Premier League          Matchweek 7  Sun  Home      D
#  11  2024-10-20  16:30  Premier League          Matchweek 8  Sun  Away      L
#  12  2024-10-24  19:45         Conf Lg         League phase  Thu  Away      W
#  13  2024-10-27  14:00  Premier League          Matchweek 9  Sun  Home      W
#  14  2024-10-30  19:45         EFL Cup         Fourth round  Wed  Away      L
#  15  2024-11-03  16:30  Premier League         Matchweek 10  Sun  Away      D
#  16  2024-11-07  20:00         Conf Lg         League phase  Thu  Home      W
#  17  2024-11-10  16:30  Premier League         Matchweek 11  Sun  Home      D
#  18  2024-11-23  12:30  Premier League         Matchweek 12  Sat  Away      W
#  19  2024-11-28  18:45         Conf Lg         League phase  Thu  Away      W
#  20  2024-12-01  13:30  Premier League         Matchweek 13  Sun  Home      W
#  21  2024-12-04  19:30  Premier League         Matchweek 14  Wed  Away      W
#  22  2024-12-08  16:30  Premier League         Matchweek 15  Sun  Away      W
#  23  2024-12-12  21:30         Conf Lg         League phase  Thu  Away      W
#  24  2024-12-15  19:00  Premier League         Matchweek 16  Sun  Home      W
#  25  2024-12-19  20:00         Conf Lg         League phase  Thu  Home      W
#  26  2024-12-22  14:00  Premier League         Matchweek 17  Sun  Away      D
#  27  2024-12-26  15:00  Premier League         Matchweek 18  Thu  Home      L
#  28  2024-12-30  19:45  Premier League         Matchweek 19  Mon  Away      L
#  29  2025-01-04  15:00  Premier League         Matchweek 20  Sat  Away      D
#  30  2025-01-11  15:00          FA Cup   Third round proper  Sat  Home      W
#  31  2025-01-14  19:30  Premier League         Matchweek 21  Tue  Home      D
#  32  2025-01-20  20:00  Premier League         Matchweek 22  Mon  Home      W
#  33  2025-01-25  17:30  Premier League         Matchweek 23  Sat  Away      L
#  34  2025-02-03  20:00  Premier League         Matchweek 24  Mon  Home    NaN
#  35  2025-02-08  20:00          FA Cup  Fourth round proper  Sat  Away    NaN
#  36  2025-02-14  20:00  Premier League         Matchweek 25  Fri  Away    NaN
#  37  2025-02-22  17:30  Premier League         Matchweek 26  Sat  Away    NaN
#  38  2025-02-25  20:15  Premier League         Matchweek 27  Tue  Home    NaN
#  39  2025-03-09  14:00  Premier League         Matchweek 28  Sun  Home    NaN
#  40  2025-03-16    NaN  Premier League         Matchweek 29  Sun  Away    NaN
#  21   4-2-3-1         5-3-2            Tony Harrington  Match Report
#  22   4-2-3-1         4-3-3             Anthony Taylor  Match Report
#  23     4-3-3       4-2-3-1             Sven Jablonski  Match Report
#  24   4-2-3-1         3-5-2               Peter Bankes  Match Report
#  25   4-2-3-1         3-5-2              Willy Delajod  Match Report
#  26   4-2-3-1         4-3-3             Chris Kavanagh  Match Report
#  27   4-2-3-1         4-5-1             Samuel Barrott  Match Report
#  28   4-2-3-1         5-4-1                John Brooks  Match Report
#  29   4-2-3-1         3-4-3               Tim Robinson  Match Report
#  30   4-1-4-1         4-5-1             Andrew Kitchen  Match Report
#  31   4-2-3-1       4-2-3-1               Robert Jones  Match Report
#  32   4-2-3-1         3-4-3               Simon Hooper  Match Report
#  33   4-2-3-1         4-3-3                John Brooks  Match Report
#  34       NaN           NaN                        NaN  Head-to-Head
#  35       NaN           NaN                        NaN  Head-to-Head
#  36       NaN           NaN                        NaN  Head-to-Head
#  37       NaN           NaN                        NaN  Head-to-Head
#  38       NaN           NaN                        NaN  Head-to-Head
#  39       NaN           NaN                        NaN  Head-to-Head
#  40       NaN           NaN                        NaN  Head-to-Head
#  41       NaN           NaN                        NaN  Head-to-Head
#  42       NaN           NaN                        NaN  Head-to-Head
#  43       NaN           NaN                        NaN  Head-to-Head
#  44       NaN           NaN                        NaN  Head-to-Head
#  45       NaN           NaN                        NaN  Head-to-Head
#  46       NaN           NaN                        NaN  Head-to-Head
#  47       NaN           NaN                        NaN  Head-to-Head
#  48       NaN           NaN                        NaN  Head-to-Head
#  49       NaN           NaN                        NaN  Head-to-Head
#
#                        Notes
#  0                       NaN
#  1                Leg 1 of 2
#  2                       NaN
#  3   Leg 2 of 2; Chelsea won
#  4                       NaN
#  5                       NaN
#  6                       NaN
#  7                       NaN
#  8                       NaN
#  9                       NaN
#  10                      NaN
#  11                      NaN
#  12                      NaN
#  13                      NaN
#  14                      NaN
#  15                      NaN
#  16                      NaN
#  17                      NaN
#  18                      NaN
#  19                      NaN
#  20                      NaN
#  21                      NaN
#  22                      NaN
#  23                      NaN
#  24                      NaN
#  25                      NaN
#  26                      NaN
#  27                      NaN
#  28                      NaN
#  29                      NaN
#  30                      NaN
#  31                      NaN
#  32                      NaN
#  33                      NaN
#  34                      NaN
#  35                      NaN
#  36                      NaN
#  37                      NaN
#  38                      NaN
#  39                      NaN
#  40                      NaN
#  41                      NaN
#  42                      NaN
#  43                      NaN
#  44                      NaN
#  45                      NaN
#  46                      NaN
#  47                      NaN
#  48                      NaN
#  49                      NaN  ]

# %%
matches[0].head()
# Out:
#          Date   Time            Comp           Round  Day Venue Result   GF  \
# 0  2024-08-18  16:30  Premier League     Matchweek 1  Sun  Home      L  0.0
# 1  2024-08-22  20:00         Conf Lg  Play-off round  Thu  Home      W  2.0
# 2  2024-08-25  14:00  Premier League     Matchweek 2  Sun  Away      W  6.0
# 3  2024-08-29  20:30         Conf Lg  Play-off round  Thu  Away      L  1.0
# 4  2024-09-01  13:30  Premier League     Matchweek 3  Sun  Home      D  1.0
#
#     GA         Opponent   xG  xGA  Poss  Attendance         Captain Formation  \
# 0  2.0  Manchester City  1.0  0.8  48.0     39818.0  Enzo Fernández   4-2-3-1
# 1  0.0   ch Servette FC  NaN  NaN   NaN     37902.0  Moisés Caicedo     4-3-3
# 2  2.0           Wolves  1.6  1.9  60.0     31235.0  Enzo Fernández   4-2-3-1
# 3  2.0   ch Servette FC  NaN  NaN   NaN     28000.0  Enzo Fernández   4-2-3-1
# 4  1.0   Crystal Palace  2.4  0.5  62.0     39298.0  Enzo Fernández   4-2-3-1
#
#   Opp Formation          Referee  Match Report                    Notes
# 0       3-2-4-1   Anthony Taylor  Match Report                      NaN
# 1       4-2-3-1  Jérémie Pignard  Match Report               Leg 1 of 2
# 2       4-2-3-1   Darren England  Match Report                      NaN
# 3       4-4-1-1   Marco Di Bello  Match Report  Leg 2 of 2; Chelsea won
# 4         3-4-3   Jarred Gillett  Match Report                      NaN

# %%
# Retrieve Chelsea shooting stats with same method
# Initialize soup object using our HTML 
soup = BeautifulSoup(data.text)

# %%
# Find all a tags in our table
links = soup.find_all('a')

# %%
# Get href property of each link - goes through each a element and find value of href property
links = [l.get("href") for l in links]

# %%
# Filter links so we only have shooting stats links
links = [l for l in links if l and 'all_comps/shooting/' in l]

# %%
links
# Out:
# ['/en/squads/cff3d9bb/2024-2025/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions',
#  '/en/squads/cff3d9bb/2024-2025/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions',
#  '/en/squads/cff3d9bb/2024-2025/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions',
#  '/en/squads/cff3d9bb/2024-2025/matchlogs/all_comps/shooting/Chelsea-Match-Logs-All-Competitions']

# %%
# Download HTML for specific link
data = requests.get(f"https://fbref.com{links[0]}")
time.sleep(60)

# %%
# Convert Shooting data to dataframe using string
shooting_data = StringIO(data.text)
shooting = pd.read_html(shooting_data, match="Shooting")[0]

# %%
shooting.head()
# Out:
#   For Chelsea                                                                \
#          Date   Time            Comp           Round  Day Venue Result   GF
# 0  2024-08-18  16:30  Premier League     Matchweek 1  Sun  Home      L  0.0
# 1  2024-08-22  20:00         Conf Lg  Play-off round  Thu  Home      W  2.0
# 2  2024-08-25  14:00  Premier League     Matchweek 2  Sun  Away      W  6.0
# 3  2024-08-29  20:30         Conf Lg  Play-off round  Thu  Away      L  1.0
# 4  2024-09-01  13:30  Premier League     Matchweek 3  Sun  Home      D  1.0
#
#                          ... Standard               Expected               \
#     GA         Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh
# 0  2.0  Manchester City  ...     17.1  0.0  0     0      1.0  1.0    0.10
# 1  0.0   ch Servette FC  ...      NaN  NaN  1     1      NaN  NaN     NaN
# 2  2.0           Wolves  ...     15.4  1.0  0     0      1.6  1.6    0.12
# 3  2.0   ch Servette FC  ...      NaN  NaN  1     1      NaN  NaN     NaN
# 4  1.0   Crystal Palace  ...     15.9  1.0  0     0      2.4  2.4    0.18
#
#                Unnamed: 25_level_0
#   G-xG np:G-xG        Match Report
# 0 -1.0    -1.0        Match Report
# 1  NaN     NaN        Match Report
# 2  4.4     4.4        Match Report
# 3  NaN     NaN        Match Report
# 4 -1.4    -1.4        Match Report
#
# [5 rows x 26 columns]

# %%
# Drop 1 index level (multi-level index)
shooting.columns = shooting.columns.droplevel()

# %%
shooting.head()
# Out:
#          Date   Time            Comp           Round  Day Venue Result   GF  \
# 0  2024-08-18  16:30  Premier League     Matchweek 1  Sun  Home      L  0.0
# 1  2024-08-22  20:00         Conf Lg  Play-off round  Thu  Home      W  2.0
# 2  2024-08-25  14:00  Premier League     Matchweek 2  Sun  Away      W  6.0
# 3  2024-08-29  20:30         Conf Lg  Play-off round  Thu  Away      L  1.0
# 4  2024-09-01  13:30  Premier League     Matchweek 3  Sun  Home      D  1.0
#
#     GA         Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0  2.0  Manchester City  ...  17.1  0.0   0      0  1.0   1.0     0.10  -1.0
# 1  0.0   ch Servette FC  ...   NaN  NaN   1      1  NaN   NaN      NaN   NaN
# 2  2.0           Wolves  ...  15.4  1.0   0      0  1.6   1.6     0.12   4.4
# 3  2.0   ch Servette FC  ...   NaN  NaN   1      1  NaN   NaN      NaN   NaN
# 4  1.0   Crystal Palace  ...  15.9  1.0   0      0  2.4   2.4     0.18  -1.4
#
#    np:G-xG  Match Report
# 0     -1.0  Match Report
# 1      NaN  Match Report
# 2      4.4  Match Report
# 3      NaN  Match Report
# 4     -1.4  Match Report
#
# [5 rows x 26 columns]

# %%
# Merge matches & shooting dataframes
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")

# %%
team_data.head()
# Out:
#          Date   Time            Comp           Round  Day Venue Result   GF  \
# 0  2024-08-18  16:30  Premier League     Matchweek 1  Sun  Home      L  0.0
# 1  2024-08-22  20:00         Conf Lg  Play-off round  Thu  Home      W  2.0
# 2  2024-08-25  14:00  Premier League     Matchweek 2  Sun  Away      W  6.0
# 3  2024-08-29  20:30         Conf Lg  Play-off round  Thu  Away      L  1.0
# 4  2024-09-01  13:30  Premier League     Matchweek 3  Sun  Home      D  1.0
#
#     GA         Opponent  ...  Opp Formation          Referee  Match Report  \
# 0  2.0  Manchester City  ...        3-2-4-1   Anthony Taylor  Match Report
# 1  0.0   ch Servette FC  ...        4-2-3-1  Jérémie Pignard  Match Report
# 2  2.0           Wolves  ...        4-2-3-1   Darren England  Match Report
# 3  2.0   ch Servette FC  ...        4-4-1-1   Marco Di Bello  Match Report
# 4  1.0   Crystal Palace  ...          3-4-3   Jarred Gillett  Match Report
#
#                      Notes    Sh  SoT  Dist   FK PK PKatt
# 0                      NaN  10.0  3.0  17.1  0.0  0     0
# 1               Leg 1 of 2   NaN  NaN   NaN  NaN  1     1
# 2                      NaN  14.0  8.0  15.4  1.0  0     0
# 3  Leg 2 of 2; Chelsea won   NaN  NaN   NaN  NaN  1     1
# 4                      NaN  13.0  7.0  15.9  1.0  0     0
#
# [5 rows x 26 columns]

# %%
shooting.shape
# Out:
# (35, 26)

# %%
matches[0].shape
# Out:
# (50, 20)

# %%
#Set up for loop to scrape multiple teams for multiple years

# %%
years = list(range(2024 ,2022, -1))

# %%
years
# Out:
# [2024, 2023]

# %%
all_matches = []

# %%
# Define URL to scrape
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]
    # time.sleep(60)

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        # time.sleep(60)
        matches_data = StringIO(data.text)
        matches = pd.read_html(matches_data, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        # time.sleep(60)
        shooting_data = StringIO(data.text)
        shooting = pd.read_html(shooting_data, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(20)

# %%
len(all_matches)
# Out:
# 43

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp         round  day venue result   gf  \
# 0   2024-08-17  12:30  Premier League   Matchweek 1  Sat  Away      W  2.0
# 1   2024-08-25  16:30  Premier League   Matchweek 2  Sun  Home      W  2.0
# 2   2024-09-01  16:00  Premier League   Matchweek 3  Sun  Away      W  3.0
# 3   2024-09-14  15:00  Premier League   Matchweek 4  Sat  Home      L  0.0
# 5   2024-09-21  15:00  Premier League   Matchweek 5  Sat  Home      W  3.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 38  2022-04-30  15:00  Premier League  Matchweek 35  Sat  Away      L    0
# 39  2022-05-08  14:00  Premier League  Matchweek 36  Sun  Home      L    0
# 40  2022-05-11  19:45  Premier League  Matchweek 21  Wed  Away      L    0
# 41  2022-05-15  14:00  Premier League  Matchweek 37  Sun  Away      D    1
# 42  2022-05-22  16:00  Premier League  Matchweek 38  Sun  Home      L    0
#
#      ga         opponent  ...  match report  notes    sh   sot  dist   fk pk  \
# 0   0.0     Ipswich Town  ...  Match Report    NaN  18.0   5.0  14.8  0.0  0
# 1   0.0        Brentford  ...  Match Report    NaN  19.0   8.0  13.6  1.0  0
# 2   0.0   Manchester Utd  ...  Match Report    NaN  11.0   3.0  13.4  0.0  0
# 3   1.0  Nott'ham Forest  ...  Match Report    NaN  14.0   5.0  14.9  0.0  0
# 5   0.0      Bournemouth  ...  Match Report    NaN  19.0  12.0  16.6  0.0  0
# ..  ...              ...  ...           ...    ...   ...   ...   ...  ... ..
# 38    2      Aston Villa  ...  Match Report    NaN   9.0   3.0  21.6  0.0  0
# 39    4         West Ham  ...  Match Report    NaN   8.0   2.0  22.2  1.0  0
# 40    3   Leicester City  ...  Match Report    NaN   9.0   5.0  17.0  0.0  0
# 41    1           Wolves  ...  Match Report    NaN  11.0   2.0  14.4  0.0  0
# 42    5        Tottenham  ...  Match Report    NaN   9.0   0.0  18.6  0.0  0
#
#    pkatt season          team
# 0      0   2024     Liverpool
# 1      0   2024     Liverpool
# 2      0   2024     Liverpool
# 3      0   2024     Liverpool
# 5      0   2024     Liverpool
# ..   ...    ...           ...
# 38     0   2023  Norwich City
# 39     0   2023  Norwich City
# 40     0   2023  Norwich City
# 41     0   2023  Norwich City
# 42     0   2023  Norwich City
#
# [1618 rows x 28 columns]

# %%
match_df.to_csv("matches.csv")
